# %% [markdown]
# # 前処理
# ---

# %%
import pandas as pd 
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np

# %%
train = pd.read_csv("./data/raw/train.csv")
test = pd.read_csv("./data/raw/test.csv")
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
def holiday(x):
    '''前日が休日か、休日明けかをフラグ化'''
    if x == "金":
        return 2 
    elif x == "月":
        return 1 
    else: 
        return 0 
    
train["holiday"] = train.week.apply(holiday)
test["holiday"] = test.week.apply(holiday)

la = LabelEncoder()
la.fit(train.week)
train["week"] = la.fit_transform(train.week)
test["week"] = la.fit_transform(test.week)
print(la.classes_)
# Out:
# ['月' '木' '水' '火' '金']

# %%
train["kcal_isna"] = train.kcal.isnull().astype(int)
test["kcal_isna"] = test.kcal.isnull().astype(int)
# 曜日ごとにカロリーに差が見られたので、欠損補完する
k_mean_mon = train[train.week == 0].loc[:, ["kcal"]].mean()
k_mean_tues = train[train.week == 1].loc[:, ["kcal"]].mean()
k_mean_wed = train[train.week == 2].loc[:, ["kcal"]].mean()
k_mean_thr = train[train.week == 3].loc[:, ["kcal"]].mean()
k_mean_fri = train[train.week == 4].loc[:, ["kcal"]].mean()

mon_tr = train[train.week == 0].loc[:, ["kcal"]].fillna(k_mean_mon)
mon_te = test[test.week == 0].loc[:, ["kcal"]].fillna(k_mean_mon)
tues_tr = train[train.week == 1].loc[:, ["kcal"]].fillna(k_mean_tues)
tues_te = test[test.week == 1].loc[:, ["kcal"]].fillna(k_mean_tues)
wed_tr = train[train.week == 2].loc[:, ["kcal"]].fillna(k_mean_wed)
wed_te = test[test.week == 2].loc[:, ["kcal"]].fillna(k_mean_wed)
thr_tr = train[train.week == 3].loc[:, ["kcal"]].fillna(k_mean_thr)
thr_te = test[test.week == 3].loc[:, ["kcal"]].fillna(k_mean_thr)
fri_tr = train[train.week == 4].loc[:, ["kcal"]].fillna(k_mean_fri)
fri_te = test[test.week == 4].loc[:, ["kcal"]].fillna(k_mean_fri)

train["kcal"] = pd.concat([mon_tr, tues_tr, wed_tr, thr_tr, fri_tr])
test["kcal"] = pd.concat([mon_te, tues_te, wed_te, thr_te, fri_te])

# %%
carry = train[train.remarks == "お楽しみメニュー"].name.value_counts()
carry = carry.index[:3]
# remarksの存在する際にはカレーの割合が高い
train["carry"] = train.name.apply(lambda x: 1 if x in carry else 0)
test["carry"] = test.name.apply(lambda x: 1 if x in carry else 0)
# remarksの頻度が多くないので特長量から削除する
train["remarks_isna"] = train.remarks.isnull().astype(int)
test["remarks_isna"] = test.remarks.isnull().astype(int)
train.drop(["remarks"], axis=1, inplace=True)
test.drop(["remarks"], axis=1, inplace=True)

# %%
train["event_isna"] = train.event.isnull().astype(int)
test["event_isna"] = test.event.isnull().astype(int)
# eventへのラベルエンコーダー
la = LabelEncoder()
la.fit(train.event.fillna("none"))
train["event"] = la.transform(train.event.fillna("none"))
test["event"] = la.transform(test.event.fillna("none"))

# %%
weather_type = train.weather.value_counts().index 

train["weather"] = train.weather.map({weather_type[0]: 0, weather_type[1]: 1, weather_type[2]: 0, weather_type[3]: 1, 
                  weather_type[4]: 2, weather_type[5]: 2, weather_type[6]: 2})
test["weather"] = test.weather.map({weather_type[0]: 0, weather_type[1]: 1, weather_type[2]: 0, weather_type[3]: 1, 
                  weather_type[4]: 2, weather_type[5]: 2, weather_type[6]: 2})

train["weather_before1"] = train.weather.shift(-1).fillna(0).astype(int)
test["weather_before1"] = test.weather.shift(-1).fillna(train.weather.iloc[-1]).astype(int)

# %%
train["precipitation"] = train.precipitation.apply(lambda x: 0 if x == "--" else x)
test["precipitation"] = test.precipitation.apply(lambda x: 0 if x == "--" else x)

# %%
train["payday"] = train.payday.fillna(0)
train["payday"] = train.payday.astype(int)
test["payday"] = test.payday.fillna(0)
test["payday"] = test.payday.astype(int)

train["payday_before1"] = train.payday.shift(-1).fillna(0).astype(int)
train["payday_after1"] = train.payday.shift(1).fillna(0).astype(int)
test["payday_before1"] = test.payday.shift(-1).fillna(0).astype(int)
test["payday_after1"] = test.payday.shift(1).fillna(train.payday.iloc[-1]).astype(int)

# %%
# 時系列変換をする
train["datetime"] = pd.to_datetime(train.datetime)
test["datetime"] = pd.to_datetime(test.datetime)

train["year"] = train.datetime.dt.year
train["month"] = train.datetime.dt.month 
train["quarter"] = train.datetime.dt.quarter
train["day"] = train.datetime.dt.day
train["day"] = (train.day-1)/(31-1)

y_2013 = train.loc[train.year == 2013, "y"].mean()
y_2014 = train.loc[train.year == 2014, "y"].mean()
# 年度によって売れ値に開きがあるのでそれぞれで埋める
train["sale_before1"] = train.y.shift(-1).fillna(y_2013)
train["moving_avg"] = train.y.shift(-1).rolling(window=5).mean().fillna(y_2013)

test["year"] = test.datetime.dt.year
test["month"] = test.datetime.dt.month 
test["quarter"] = test.datetime.dt.quarter
test["day"] = test.datetime.dt.day
test["day"] = (test.day-1)/(31-1)

# %%
# 季節別の温度平均の割合
q_1_tem = train.loc[train.quarter == 1, "temperature"].mean()
q_2_tem = train.loc[train.quarter == 2, "temperature"].mean()
q_3_tem = train.loc[train.quarter == 3, "temperature"].mean()
q_4_tem = train.loc[train.quarter == 4, "temperature"].mean()


q_1r = train.loc[train.quarter == 1, "temperature"] / q_1_tem
q_2r = train.loc[train.quarter == 2, "temperature"] / q_2_tem
q_3r = train.loc[train.quarter == 3, "temperature"] / q_3_tem
q_4r = train.loc[train.quarter == 4, "temperature"] / q_4_tem

train["temperature_avg"] = pd.concat([q_1r, q_2r, q_3r, q_4r])
test["temperature_avg"] = test.temperature/q_4_tem

# %%
# 不要なカラムの削除
train.drop(["name", "datetime"], axis=1, inplace=True)
test.drop(["name", "datetime"], axis=1, inplace=True)

# %%
# # monthのターゲットエンコーダーをする
from src.utils.category_transform import TargetEncoder
train_ = train.copy()

tag = TargetEncoder()
tag.fit(train.drop(["y"], axis=1), train[["y"]], col="month")
train, test = tag.transform(test)
month_mean = train.loc[train.year == 2014, "month"].mean()
test["month"] = test.month.fillna(month_mean)
train["y"] = train_["y"]

# %%
train.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_602c9_row0_col0, #T_602c9_row1_col1, #T_602c9_row2_col2, #T_602c9_row3_col3, #T_602c9_row4_col4, #T_602c9_row5_col5, #T_602c9_row6_col6, #T_602c9_row7_col7, #T_602c9_row8_col8, #T_602c9_row9_col9, #T_602c9_row10_col10, #T_602c9_row11_col11, #T_602c9_row12_col12, #T_602c9_row13_col13, #T_602c9_row14_col14, #T_602c9_row15_col15, #T_602c9_row16_col16, #T_602c9_row17_col17, #T_602c9_row18_col18, #T_602c9_row19_col19, #T_602c9_row20_col20, #T_602c9_row21_col21, #T_602c9_row22_col22 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col1, #T_602c9_row15_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col2, #T_602c9_row5_col7, #T_602c9_row7_col13 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_602c9_row0_col4, #T_602c9_row10_col13, #T_602c9_row20_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col5, #T_602c9_row6_col14, #T_602c9_row18_col1, #T_602c9_row19_col21, #T_602c9_row21_col2, #T_602c9_row22_col5, #T_602c9_row22_col21 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col6, #T_602c9_row1_col22, #T_602c9_row4_col15, #T_602c9_row7_col15, #T_602c9_row13_col15, #T_602c9_row14_col15, #T_602c9_row17_col16 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_602c9_row0_col7, #T_602c9_row9_col6, #T_602c9_row10_col20 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_602c9_row0_col8 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_602c9_row0_col9, #T_602c9_row6_col21 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_602c9_row0_col10, #T_602c9_row13_col2, #T_602c9_row15_col1, #T_602c9_row15_col18, #T_602c9_row16_col2, #T_602c9_row16_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col11, #T_602c9_row4_col20, #T_602c9_row18_col11 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_602c9_row0_col12, #T_602c9_row0_col21, #T_602c9_row11_col0, #T_602c9_row11_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col13, #T_602c9_row3_col1, #T_602c9_row4_col2, #T_602c9_row6_col13, #T_602c9_row8_col4, #T_602c9_row10_col4, #T_602c9_row11_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col14, #T_602c9_row3_col13, #T_602c9_row18_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col15, #T_602c9_row0_col16, #T_602c9_row2_col15, #T_602c9_row4_col8, #T_602c9_row11_col6, #T_602c9_row21_col15 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_602c9_row0_col17, #T_602c9_row1_col10, #T_602c9_row9_col17, #T_602c9_row22_col17 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_602c9_row0_col18, #T_602c9_row5_col4, #T_602c9_row11_col14, #T_602c9_row15_col4, #T_602c9_row16_col13, #T_602c9_row17_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_602c9_row0_col19, #T_602c9_row0_col20, #T_602c9_row1_col15, #T_602c9_row4_col16, #T_602c9_row5_col6, #T_602c9_row7_col22, #T_602c9_row11_col8, #T_602c9_row13_col16, #T_602c9_row14_col22, #T_602c9_row20_col17 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_602c9_row0_col22, #T_602c9_row18_col17 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_602c9_row1_col0, #T_602c9_row2_col4, #T_602c9_row3_col10, #T_602c9_row7_col4, #T_602c9_row9_col4, #T_602c9_row15_col21, #T_602c9_row17_col21, #T_602c9_row19_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col2, #T_602c9_row4_col21, #T_602c9_row6_col4, #T_602c9_row8_col13, #T_602c9_row10_col21, #T_602c9_row19_col2, #T_602c9_row20_col14, #T_602c9_row22_col15 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col3, #T_602c9_row1_col20, #T_602c9_row5_col11, #T_602c9_row12_col11, #T_602c9_row21_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_602c9_row1_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col5, #T_602c9_row5_col20 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_602c9_row1_col6, #T_602c9_row1_col17, #T_602c9_row9_col16, #T_602c9_row18_col22 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_602c9_row1_col7, #T_602c9_row16_col1, #T_602c9_row21_col12, #T_602c9_row22_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col8, #T_602c9_row4_col9 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_602c9_row1_col9, #T_602c9_row1_col13, #T_602c9_row9_col14, #T_602c9_row12_col21, #T_602c9_row13_col7, #T_602c9_row14_col0, #T_602c9_row14_col7, #T_602c9_row17_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_602c9_row1_col11, #T_602c9_row8_col3, #T_602c9_row18_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_602c9_row1_col12, #T_602c9_row22_col12 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col14, #T_602c9_row6_col2, #T_602c9_row15_col22, #T_602c9_row20_col15 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col16, #T_602c9_row9_col7, #T_602c9_row17_col11 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_602c9_row1_col18, #T_602c9_row21_col13 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_602c9_row1_col19, #T_602c9_row5_col3, #T_602c9_row16_col3, #T_602c9_row17_col3, #T_602c9_row18_col16, #T_602c9_row19_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_602c9_row1_col21, #T_602c9_row8_col2, #T_602c9_row9_col2, #T_602c9_row10_col18, #T_602c9_row16_col21, #T_602c9_row19_col14 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_602c9_row2_col0, #T_602c9_row5_col16, #T_602c9_row9_col19, #T_602c9_row13_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_602c9_row2_col1, #T_602c9_row13_col12, #T_602c9_row20_col13, #T_602c9_row22_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_602c9_row2_col3, #T_602c9_row2_col22, #T_602c9_row3_col15, #T_602c9_row6_col9, #T_602c9_row15_col11, #T_602c9_row17_col20, #T_602c9_row20_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_602c9_row2_col5, #T_602c9_row10_col5, #T_602c9_row14_col12, #T_602c9_row20_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_602c9_row2_col6, #T_602c9_row2_col19, #T_602c9_row8_col0, #T_602c9_row18_col20, #T_602c9_row19_col17 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_602c9_row2_col7, #T_602c9_row15_col0, #T_602c9_row16_col0, #T_602c9_row16_col9, #T_602c9_row21_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_602c9_row2_col8, #T_602c9_row3_col8, #T_602c9_row8_col7, #T_602c9_row18_col6 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_602c9_row2_col9, #T_602c9_row17_col9, #T_602c9_row21_col18 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_602c9_row2_col10, #T_602c9_row18_col10, #T_602c9_row20_col9, #T_602c9_row21_col10 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_602c9_row2_col11, #T_602c9_row4_col11, #T_602c9_row13_col11, #T_602c9_row14_col11, #T_602c9_row18_col3, #T_602c9_row21_col11 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_602c9_row2_col12, #T_602c9_row8_col21, #T_602c9_row20_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_602c9_row2_col13, #T_602c9_row12_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_602c9_row2_col14 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_602c9_row2_col16, #T_602c9_row14_col8, #T_602c9_row19_col11, #T_602c9_row20_col10, #T_602c9_row22_col9 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_602c9_row2_col17, #T_602c9_row10_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_602c9_row2_col18 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_602c9_row2_col20, #T_602c9_row6_col3, #T_602c9_row8_col11 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_602c9_row2_col21, #T_602c9_row5_col13, #T_602c9_row9_col18, #T_602c9_row11_col5, #T_602c9_row12_col2, #T_602c9_row12_col13, #T_602c9_row14_col5, #T_602c9_row15_col13 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_602c9_row3_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_602c9_row3_col2, #T_602c9_row8_col12, #T_602c9_row15_col16 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_60

# %%
train.head()
# Out:
#    week  soldout        kcal  event  payday  weather precipitation  \
# 0     0        0  398.970588      0       0        0             0
# 1     3        1  406.714286      0       0        0             0
# 2     2        0  406.621622      0       0        0             0
# 3     1        1  403.540541      0       0        0             0
# 4     4        1  406.782609      0       0        0             0
#
#    temperature  holiday  kcal_isna  ...  payday_before1  payday_after1  year  \
# 0         19.8        1          1  ...               0              0  2013
# 1         17.0        0          1  ...               0              0  2013
# 2         15.5        0          1  ...               0              0  2013
# 3         15.2        0          1  ...               0              0  2013
# 4         16.1        2          1  ...               0              0  2013
#
#         month  quarter       day  sale_before1  moving_avg  temperature_avg  \
# 0  131.666667        4  0.566667         101.0  134.321429         1.558179
# 1  131.666667        4  0.600000         118.0  134.321429         1.337830
# 2  122.125000        4  0.633333         120.0  134.321429         1.219786
# 3  131.666667        4  0.666667         130.0  134.321429         1.196178
# 4  120.142857        4  0.700000         135.0  120.800000         1.267004
#
#      y
# 0   90
# 1  101
# 2  118
# 3  120
# 4  130
#
# [5 rows x 24 columns]

# %%
train.to_csv("./data/processed/train.csv", index=False)
test.to_csv("./data/processed/test.csv", index=False)
